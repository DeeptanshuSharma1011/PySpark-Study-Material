#      ----------------------------------- - 429.4/450.1 MB 28.2 MB/s eta 0:00:01
#      ----------------------------------- - 435.2/450.1 MB 28.2 MB/s eta 0:00:01
#      ------------------------------------  440.7/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  446.7/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  450.1/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  450.1/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  450.1/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  450.1/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  450.1/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  450.1/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  450.1/450.1 MB 28.1 MB/s eta 0:00:01
#      ------------------------------------  450.1/450.1 MB 28.1 MB/s eta 0:00:01
#      ---------------------------------------- 450.1/450.1 MB 23.8 MB/s  0:00:17
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting py4j<0.10.9.10,>=0.10.9.7 (from pyspark)
#   Downloading py4j-0.10.9.9-py2.py3-none-any.whl.metadata (1.3 kB)
# Downloading py4j-0.10.9.9-py2.py3-none-any.whl (203 kB)
# Building wheels for collected packages: pyspark
#   Building wheel for pyspark (pyproject.toml): started
#   Building wheel for pyspark (pyproject.toml): still running...
#   Building wheel for pyspark (pyproject.toml): finished with status 'done'
#   Created wheel for pyspark: filename=pyspark-4.2.0-py2.py3-none-any.whl size=450891374 sha256=b27ed1b49f94c4c2e4c73a32468915d7c90e05b6135a457435c4aac8562d7ba7
#   Stored in directory: c:\users\lenovo\appdata\local\pip\cache\wheels\b2\35\e8\0f0feeae799066fbc77af369b7c2ea3f879504cb8f0f27d94c
# Successfully built pyspark
# Installing collected packages: py4j, pyspark
#
#    ---------------------------------------- 0/2 [py4j]
#    ---------------------------------------- 0/2 [py4j]
#    ---------------------------------------- 0/2 [py4j]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    -------------------- ------------------- 1/2 [pyspark]
#    ---------------------------------------- 2/2 [pyspark]
#
# Successfully installed py4j-0.10.9.9 pyspark-4.2.0
# WARNING: Cache entry deserialization failed, entry ignored
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pyspark

# %%
import pandas as pd
pd.read_csv('test1.csv')
# Out:
#          Name  Age
# 0  Deeptanshu   21
# 1    Parinita   25
# 2      Naveen   57
# 3     Vartika   53

# %%
from pyspark.sql import SparkSession

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-98V5M1R:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df_pyspark = spark.read.csv('test1.csv')

# %%
df_pyspark
# Out:
# DataFrame[_c0: string, _c1: string]

# %%
df_pyspark.show()
# Out:
# +----------+---+
# |       _c0|_c1|
# +----------+---+
# |      Name|Age|
# |Deeptanshu| 21|
# |  Parinita| 25|
# |    Naveen| 57|
# |   Vartika| 53|
# +----------+---+

# %%
df_pyspark = spark.read.option('header', 'true').csv('test1.csv')

# %%
df_pyspark.show()
# Out:
# +----------+---+
# |      Name|Age|
# +----------+---+
# |Deeptanshu| 21|
# |  Parinita| 25|
# |    Naveen| 57|
# |   Vartika| 53|
# +----------+---+

# %%
type(df_pyspark)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df_pyspark.head(3)
# Out:
# [Row(Name='Deeptanshu', Age='21'),
#  Row(Name='Parinita', Age='25'),
#  Row(Name='Naveen', Age='57')]

# %%
df_pyspark.printSchema()
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- Age: string (nullable = true)

# %%
from pyspark.sql import SparkSession

# %%
spark = SparkSession.builder.appName('Dataframe').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://DESKTOP-98V5M1R:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.2.0</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Practice</code></dd>
#             </dl>
#         </div>
#
#             </div>
